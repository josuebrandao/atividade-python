# %% [markdown]
# <a href="https://colab.research.google.com/github/josuebrandao/atividade-python/blob/main/atividade03-sobre%20github.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Atividade 01 — Introdução ao Python

# %%
print("Minha primeira atividade no Google Colab")
print("Aprendendo Python e GitHub")
# Out:
# Minha primeira atividade no Google Colab
# Aprendendo Python e GitHub

# %% [markdown]
# #Atividade 02 — Introdução ao Python

# %%
nome_da_disciplina=input("digite o nome da disciplina: ")
conteudo_estudado=input("digite o conteudo estudado: ")
numero_atividade=input("digite o numero da atividade: ")
print(f"a disciplina estudada é {nome_da_disciplina}, o conteudo é {conteudo_estudado} e o numero é {numero_atividade}")
# Out:
# digite o nome da disciplina: algoritimo
# digite o conteudo estudado: git
# digite o numero da atividade: 20
# a disciplina estudada é algoritimo, o conteudo é git e o numero é 20

# %%
print("Aprendendo versionamento de projetos!")
# Out:
# Aprendendo versionamento de projetos!
